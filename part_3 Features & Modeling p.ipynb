# %% [markdown]
# # Saudi League Analysis
# # Part 3: Modeling

# %%
import numpy as np 
import pandas as pd

import seaborn as sns

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Content:
# ## 1- Load Data
# ## 2- Data Preparation
# - Correlation Based
# - Recursive Feature Elimination
#
# ## 3- Models Selection
# - Check Different Models
# - Hyper-parameters Tuning
#
# ## 4- Model Evaluation

# %% [markdown]
# ***
# # 1- ***Load Data***
# ***

# %%
p14 = pd.read_csv('p_period 14-21')
p18 = pd.read_csv('p_period 18-21')
p14.drop('index', axis=1, inplace=True)
p18.drop('index', axis=1, inplace=True)
p18 = p18.drop(['90s.1','Gls.2','PK.1','PKatt.1','Born.1','MP.1','90s.2'], axis=1)

# %%
print(p14.shape)
print(p18.shape)
# Out:
# (3719, 42)
# (1991, 53)

# %% [markdown]
# - 156.198
# - 105.523

# %% [markdown]
# ***
# # 1- ***Data Preparation***
# ***

# %%
p14.head(3)
# Out:
#    Rk               Player Nation Pos       Squad   Age    Born  MP  Starts  \
# 0   1  Malek AlAbadalmanam    KSA   F    Al-Fayha  23.0  1998.0  22       8
# 1   2        Saleh AlAbbas    KSA   M  Al-Faisaly  27.0  1993.0   9       1
# 2   3        Hamad AlAbdan    KSA   M    Al-Hazem  21.0  2000.0   8       3
#
#    Min  ...  Subs  Mn/Sub  unSub   PPM  onG  onGA  +/-  +/-90  On-Off  year
# 0  735  ...    14    14.0      2  1.32  7.0   4.0  3.0   0.37    0.64  2021
# 1  247  ...     8    24.0     12  0.22  2.0   5.0 -3.0  -1.09   -0.87  2021
# 2  298  ...     5    19.0      2  1.00  1.0   5.0 -4.0  -1.21   -0.35  2021
#
# [3 rows x 42 columns]

# %%
p18.head(3)
# Out:
#    Rk               Player Nation Pos       Squad   Age    Born  MP  Starts  \
# 0   1  Malek AlAbadalmanam    KSA   F    Al-Fayha  23.0  1998.0  22       8
# 1   2        Saleh AlAbbas    KSA   M  Al-Faisaly  27.0  1993.0   9       1
# 2   3        Hamad AlAbdan    KSA   M    Al-Hazem  21.0  2000.0   8       3
#
#    Min  ...  +/-90  On-Off  Fls  Fld  Off  Crs  Int  TklW  OG  year
# 0  735  ...   0.37    0.64   27   12    3    1    1     1   0  2021
# 1  247  ...  -1.09   -0.87    5    7    1    1    1     1   0  2021
# 2  298  ...  -1.21   -0.35    3    0    0    2    1     2   0  2021
#
# [3 rows x 53 columns]

# %%
print(p14.columns)
print()
print(p14.info())
# Out:
# Index(['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', 'MP', 'Starts',
#        'Min', '90s', 'Gls', 'Ast', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR',
#        'Gls.1', 'Ast.1', 'G+A', 'G-PK.1', 'G+A-PK', 'index.1', 'MP.1', 'Min.1',
#        'Mn/MP', 'Min%', '90s.1', 'Starts.1', 'Mn/Start', 'Compl', 'Subs',
#        'Mn/Sub', 'unSub', 'PPM', 'onG', 'onGA', '+/-', '+/-90', 'On-Off',
#        'year'],
#       dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3719 entries, 0 to 3718
# Data columns (total 42 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rk        3719 non-null   int64
#  1   Player    3719 non-null   object
#  2   Nation    3719 non-null   object
#  3   Pos       3719 non-null   object
#  4   Squad     3719 non-null   object
#  5   Age       3719 non-null   float64
#  6   Born      3719 non-null   float64
#  7   MP        3719 non-null   int64
#  8   Starts    3719 non-null   int64
#  9   Min       3719 non-null   int64
#  10  90s       3719 non-null   float64
#  11  Gls       3719 non-null   int64
#  12  Ast       3719 non-null   int64
#  13  G-PK      3719 non-null   int64
#  14  PK        3719 non-null   int64
#  15  PKatt     3719 non-null   int64
#  16  CrdY      3719 non-null   int64
#  17  CrdR      3719 non-null   int64
#  18  Gls.1     3719 non-null   float64
#  19  Ast.1     3719 non-null   float64
#  20  G+A       3719 non-null   float64
#  21  G-PK.1    3719 non-null   float64
#  22  G+A-PK    3719 non-null   float64
#  23  index.1   3719 non-null   int64
#  24  MP.1      3719 non-null   int64
#  25  Min.1     3719 non-null   float64
#  26  Mn/MP     3719 non-null   float64
#  27  Min%      3719 non-null   float64
#  28  90s.1     3719 non-null   float64
#  29  Starts.1  3719 non-null   int64
#  30  Mn/Start  3719 non-null   float64
#  31  Compl     3719 non-null   float64
#  32  Subs      3719 non-null   int64
#  33  Mn/Sub    3719 non-null   float64
#  34  unSub     3719 non-null   int64
#  35  PPM       3719 non-null   float64
#  36  onG       3719 non-null   float64
#  37  onGA      3719 non-null   float64
#  38  +/-       3719 non-null   float64
#  39  +/-90     3719 non-null   float64
#  40  On-Off    3719 non-null   float64
#  41  year      3719 non-null   int64
# dtypes: float64(21), int64(17), object(4)
# memory usage: 1.2+ MB
# None

# %% [markdown]
# ***Label Encoder***

# %% [markdown]
# - D = 0
# - F = 1
# - G = 2
# - M = 3

# %%
lbl = LabelEncoder()
p14.Pos = lbl.fit_transform(p14.Pos)
p18.Pos = lbl.fit_transform(p18.Pos)

# %%
p14['Nation'].value_counts()
# Out:
# KSA    2692
# BRA     243
# ALG      58
# MAR      56
# TUN      46
#        ...
# GAB       1
# SUD       1
# BEN       1
# LTU       1
# LIB       1
# Name: Nation, Length: 100, dtype: int64

# %%
p14['Nation'] = p14['Nation'].apply(lambda x: 1 if x =='KSA' else 0)
p18['Nation'] = p18['Nation'].apply(lambda x: 1 if x =='KSA' else 0)

# %%
p14.drop('Squad',axis=1, inplace=True)
p18.drop('Squad',axis=1, inplace=True)

# %%
p14.head()
# Out:
#    Rk               Player  Nation  Pos   Age    Born  MP  Starts   Min   90s  \
# 0   1  Malek AlAbadalmanam       1    1  23.0  1998.0  22       8   735   8.2
# 1   2        Saleh AlAbbas       1    3  27.0  1993.0   9       1   247   2.7
# 2   3        Hamad AlAbdan       1    3  21.0  2000.0   8       3   298   3.3
# 3   4     Ayoub Abdellaoui       0    0  28.0  1993.0  22      19  1598  17.8
# 4   5      Saud Abdulhamid       1    0  22.0  1999.0  13      10   970  10.8
#
#    ...  Subs  Mn/Sub  unSub   PPM   onG  onGA   +/-  +/-90  On-Off  year
# 0  ...    14    14.0      2  1.32   7.0   4.0   3.0   0.37    0.64  2021
# 1  ...     8    24.0     12  0.22   2.0   5.0  -3.0  -1.09   -0.87  2021
# 2  ...     5    19.0      2  1.00   1.0   5.0  -4.0  -1.21   -0.35  2021
# 3  ...     3    13.0      0  0.95  19.0  25.0  -6.0  -0.34   -0.26  2021
# 4  ...     3    31.0      0  2.77  29.0   6.0  23.0   2.13    1.51  2021
#
# [5 rows x 41 columns]

# %%
p18.head()
# Out:
#    Rk               Player  Nation  Pos   Age    Born  MP  Starts   Min   90s  \
# 0   1  Malek AlAbadalmanam       1    1  23.0  1998.0  22       8   735   8.2
# 1   2        Saleh AlAbbas       1    3  27.0  1993.0   9       1   247   2.7
# 2   3        Hamad AlAbdan       1    3  21.0  2000.0   8       3   298   3.3
# 3   4     Ayoub Abdellaoui       0    0  28.0  1993.0  22      19  1598  17.8
# 4   5      Saud Abdulhamid       1    0  22.0  1999.0  13      10   970  10.8
#
#    ...  +/-90  On-Off  Fls  Fld  Off  Crs  Int  TklW  OG  year
# 0  ...   0.37    0.64   27   12    3    1    1     1   0  2021
# 1  ...  -1.09   -0.87    5    7    1    1    1     1   0  2021
# 2  ...  -1.21   -0.35    3    0    0    2    1     2   0  2021
# 3  ...  -0.34   -0.26   23   20    1   22   21    11   0  2021
# 4  ...   2.13    1.51   20   15    0   43    7    24   0  2021
#
# [5 rows x 52 columns]

# %%
pp18 = p18.copy()
pp14 = p14.copy()

# %%
pp14.columns
# Out:
# Index(['Rk', 'Player', 'Nation', 'Pos', 'Age', 'Born', 'MP', 'Starts', 'Min',
#        '90s', 'Gls', 'Ast', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'Gls.1',
#        'Ast.1', 'G+A', 'G-PK.1', 'G+A-PK', 'index.1', 'MP.1', 'Min.1', 'Mn/MP',
#        'Min%', '90s.1', 'Starts.1', 'Mn/Start', 'Compl', 'Subs', 'Mn/Sub',
#        'unSub', 'PPM', 'onG', 'onGA', '+/-', '+/-90', 'On-Off', 'year'],
#       dtype='object')

# %%
pp18 = pp18.drop(['Rk', 'Player','Born', 'Starts.1', 'Min.1' , 'year'],axis=1)
pp14 = pp14.drop(['Rk', 'Player','Born', 'Starts.1', 'Min.1' , 'year', 'index.1', '90s.1'], axis=1)

# %%
pp18.head()
# Out:
#    Nation  Pos   Age  MP  Starts   Min   90s  Gls  Ast  G-PK  ...   +/-  \
# 0       1    1  23.0  22       8   735   8.2    4    0     4  ...   3.0
# 1       1    3  27.0   9       1   247   2.7    0    0     0  ...  -3.0
# 2       1    3  21.0   8       3   298   3.3    0    0     0  ...  -4.0
# 3       0    0  28.0  22      19  1598  17.8    0    0     0  ...  -6.0
# 4       1    0  22.0  13      10   970  10.8    0    2     0  ...  23.0
#
#    +/-90  On-Off  Fls  Fld  Off  Crs  Int  TklW  OG
# 0   0.37    0.64   27   12    3    1    1     1   0
# 1  -1.09   -0.87    5    7    1    1    1     1   0
# 2  -1.21   -0.35    3    0    0    2    1     2   0
# 3  -0.34   -0.26   23   20    1   22   21    11   0
# 4   2.13    1.51   20   15    0   43    7    24   0
#
# [5 rows x 46 columns]

# %%
pp14.head()
# Out:
#    Nation  Pos   Age  MP  Starts   Min   90s  Gls  Ast  G-PK  ...  Compl  \
# 0       1    1  23.0  22       8   735   8.2    4    0     4  ...    2.0
# 1       1    3  27.0   9       1   247   2.7    0    0     0  ...    0.0
# 2       1    3  21.0   8       3   298   3.3    0    0     0  ...    0.0
# 3       0    0  28.0  22      19  1598  17.8    0    0     0  ...   14.0
# 4       1    0  22.0  13      10   970  10.8    0    2     0  ...    9.0
#
#    Subs  Mn/Sub  unSub   PPM   onG  onGA   +/-  +/-90  On-Off
# 0    14    14.0      2  1.32   7.0   4.0   3.0   0.37    0.64
# 1     8    24.0     12  0.22   2.0   5.0  -3.0  -1.09   -0.87
# 2     5    19.0      2  1.00   1.0   5.0  -4.0  -1.21   -0.35
# 3     3    13.0      0  0.95  19.0  25.0  -6.0  -0.34   -0.26
# 4     3    31.0      0  2.77  29.0   6.0  23.0   2.13    1.51
#
# [5 rows x 33 columns]

# %%
X = pp14[['Nation', 'Pos', 'Age', 'MP', 'Starts', 'Min', '90s', 'Gls', 'Ast',
       'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'Gls.1', 'Ast.1', 'G+A',
       'G-PK.1', 'G+A-PK', 'MP.1', 'Mn/MP', 'Min%', 'Mn/Start', 'Compl',
       'Subs', 'Mn/Sub', 'unSub', 'PPM', 'onG', 'onGA', '+/-', '+/-90',
       'On-Off']]
y = X.values

# %%
sns.distplot(y,kde = False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\holol\Desktop\work speas\Data_Scientsts\python\football analysis\Saudi Arabia Football\Players\part_3 Features & Modeling.ipynb Cell 26 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/holol/Desktop/work%20speas/Data_Scientsts/python/football%20analysis/Saudi%20Arabia%20Football/Players/part_3%20Features%20%26%20Modeling.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> sns.displot(y,kde = False)
#
# File c:\Users\holol\anaconda3\lib\site-packages\seaborn\distributions.py:2274, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2271 if p.univariate:
#    2273     _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2274     p.plot_univariate_histogram(**hist_kws)
#    2276 else:
#    2278     _assign_default_kwargs(hist_kws, p.plot_bivariate_histogram, histplot)
#
# File c:\Users\holol\anaconda3\lib\site-packages\seaborn\distributions.py:565, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     560 if element == "bars":
#     561
#     562     # Use matplotlib bar plotting
#     564     plot_func = ax.bar if self.data_variable == "x" else ax.barh
# --> 565     artists = plot_func(
#     566         hist["edges"],
#     567         hist["heights"] - bottom,
#     568         hist["widths"],
#     569         bottom,
#     570         align="edge",
#     571         **artist_kws,
#     572     )
#     573     for bar in artists:
#     574         if self.data_variable == "x":
#
# File c:\Users\holol\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File c:\Users\holol\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:2409, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2407     elif orientation == 'horizontal':
#    2408         r.sticky_edges.x.append(l)
# -> 2409     self.add_patch(r)
#    2410     patches.append(r)
#    2412 if xerr is not None or yerr is not None:
#
# File c:\Users\holol\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2357, in _AxesBase.add_patch(self, p)
#    2355 self._set_artist_props(p)
#    2356 if p.get_clip_path() is None:
# -> 2357     p.set_clip_path(self.patch)
#    2358 self._update_patch_limits(p)
#    2359 self._children.append(p)
#
# File c:\Users\holol\anaconda3\lib\site-packages\matplotlib\artist.py:790, in Artist.set_clip_path(self, path, transform)
#     787 if transform is None:
#     788     if isinstance(path, Rectangle):
#     789         self.clipbox = TransformedBbox(Bbox.unit(),
# --> 790                                        path.get_transform())
#     791         self._clippath = None
#     792         success = True
#
# File c:\Users\holol\anaconda3\lib\site-packages\matplotlib\patches.py:278, in Patch.get_transform(self)
#     276 def get_transform(self):
#     277     """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 278     return self.get_patch_transform() + artist.Artist.get_transform(self)
#
# File c:\Users\holol\anaconda3\lib\site-packages\matplotlib\patches.py:754, in Rectangle.get_patch_transform(self)
#     747 def get_patch_transform(self):
#     748     # Note: This cannot be called until after this has been added to
#     749     # an Axes, otherwise unit conversion will fail. This makes it very
#     750     # important to call the accessor method and not directly access the
#     751     # transformation member variable.
#     752     bbox = self.get_bbox()
#     753     return (transforms.BboxTransformTo(bbox)
# --> 754             + transforms.Affine2D().rotate_deg_around(
#     755                 bbox.x0, bbox.y0, self.angle))
#
# File c:\Users\holol\anaconda3\lib\site-packages\matplotlib\transforms.py:2042, in Affine2D.rotate_deg_around(self, x, y, degrees)
#    2040 # Cast to float to avoid wraparound issues with uint8's
#    2041 x, y = float(x), float(y)
# -> 2042 return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#
# File c:\Users\holol\anaconda3\lib\site-packages\matplotlib\transforms.py:2020, in Affine2D.rotate_deg(self, degrees)
#    2012 def rotate_deg(self, degrees):
#    2013     """
#    2014     Add a rotation (in degrees) to this transform in place.
#    2015
#    (...)
#    2018     and :meth:`scale`.
#    2019     """
# -> 2020     return self.rotate(math.radians(degrees))
#
# File c:\Users\holol\anaconda3\lib\site-packages\matplotlib\transforms.py:2008, in Affine2D.rotate(self, theta)
#    2005 b = math.sin(theta)
#    2006 rotate_mtx = np.array([[a, -b, 0.0], [b, a, 0.0], [0.0, 0.0, 1.0]],
#    2007                       float)
# -> 2008 self._mtx = np.dot(rotate_mtx, self._mtx)
#    2009 self.invalidate()
#    2010 return self
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
